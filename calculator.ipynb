# %% [markdown]
# <a href="https://colab.research.google.com/github/Rehma06/Programming-in-VS-Code/blob/main/calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function for addition
def add(num1, num2):
    return num1 + num2

# %%
# Function for subtraction
def subtract(num1, num2):
    return num1 - num2

# %%
# Function for multiplication
def multiply(num1, num2):
    return num1 * num2

# %%
# Function for division
def divide(num1, num2):
    if num2 == 0:
        return "Cannot divide by zero"
    return num1 / num2

# %%
# Function for modulus
def modulus(num1, num2):
    if num2 == 0:
        return "Cannot divide by zero"
    return num1 % num2

# %%
# Funcion for exponentials
def exponentials(num1, num2):
    return num1 ** num2

# %%
# Function for getting input
def get_input():
    num1 = float(input("Enter your 1st number:"))
    num2 = float(input("Enter your 2nd number:"))
    return num1, num2

# %%
# Function to get input
def take_input():
    print("Select operation:")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Modulus")
    print("6. Exponentials")

# %%
# Main Calculator
def calculator():
    num1, num2 = get_input()

    take_input()

    choice=int(input("Enter choice(1/2/3/4/5/6):"))

    if choice==1:
        print(f'{num1}+{num2}{add(num1,num2)}')

    elif choice==2:
        print(f'{num1}-{num2}{subtract(num1,num2)}')

    elif choice==3:
        print(f'{num1}*{num2}{multiply(num1,num2)}')

    elif choice==4:
        print(f'{num1}/{num2}{divide(num1,num2)}')

    elif choice==5:
        print(f'{num1}%{num2}{modulus(num1,num2)}')

    elif choice==6:
        print(f'{num1}**{num2}{exponentials(num1,num2)}')

    else:
        print("Invalid input")

# %%
calculator()
# Out:
# Enter your 1st number:13
# Enter your 2nd number:7
# Select operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponentials
# Enter choice(1/2/3/4/5/6):6
# 13.0**7.062748517.0
